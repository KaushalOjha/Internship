# %% [markdown]
# # Assignment 3
# ### Q1 Write a python program which searches all the product under a particular product from www.amazon.in.
# ### The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# ### for guitars.
# ### Q2 In the above question, now scrape the following details of each product listed in first 3 pages of your
# ### search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# ### results then scrape all the products available under that productname. Details to be scraped are: "Brand
# ###  Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability"and “Product
# ###  URL”. In case, if any of the details are missing for any of the productthen replace it by “-“.

# %%
# !pip install selenium

from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import requests
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: selenium in e:\datatrained\anaconda\lib\site-packages (4.1.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in e:\datatrained\anaconda\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in e:\datatrained\anaconda\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in e:\datatrained\anaconda\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: outcome in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: cffi>=1.14 in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: sortedcontainers in e:\datatrained\anaconda\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in e:\datatrained\anaconda\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in e:\datatrained\anaconda\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in e:\datatrained\anaconda\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in e:\datatrained\anaconda\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in e:\datatrained\anaconda\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in e:\datatrained\anaconda\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in e:\datatrained\anaconda\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)

# %%
# Run the driver
driver = webdriver.Chrome('chromedriver.exe')

# inserting url to driver
url1 = 'https://www.amazon.in/'
driver.get(url1)

# %%
#to find element
srch_title_xpath = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
srch_title_xpath
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="45ed580972e844d8ae81b172f566cb38", element="73e37a2c-010a-41fa-9ecb-1020f7ee5ac7")>

# %%
# Input from user "watch"
search_prod=input('type your text here:')
# Out:
# type your text here:watch

# %%
#to fill search colomn 
srch_title_xpath.send_keys(search_prod)

# %%
#to click on search button
searchbtn = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
searchbtn.click()

# %% [markdown]
# ### In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that productname. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability"and “Product URL”. In case, if any of the details are missing for any of the productthen replace it by “-“.

# %%
# to fetch brand names
Brand_name = driver.find_elements_by_xpath('//span[@class="a-size-base-plus a-color-base"]')
len(Brand_name)
# Out:
# 68

# %%
# Creating list of brand name

Brand = []
for i in Brand_name:
    Brand.append(i.text)

Brand
# Out:
# ['SELLORIA',
#  'Generic',
#  'casera',
#  'Generic',
#  'boAt',
#  'SHREE NOVA',
#  'Noise',
#  'boAt',
#  'Shocknshop',
#  'RIZZER',
#  'Fire-Boltt',
#  'boAt',
#  'Adipin',
#  'REDUX',
#  'TIMEWEAR',
#  'Fire-Boltt',
#  'boAt',
#  'Fastrack',
#  'PTron',
#  'MARVIK',
#  'Casio',
#  'Fastrack',
#  'SWISSTONE',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'SELLORIA',
#  'SWISSTYLE',
#  'Britex',
#  'Goldenize fashion',
#  'Fire-Boltt',
#  'boAt',
#  'ITRUE',
#  'Casio',
#  'TIMEWEAR',
#  'DIVALTH',
#  'VILLS LAURRENS',
#  'Shocknshop',
#  'Fire-Boltt',
#  'DECORVAIZ',
#  'SELLORIA',
#  'Fastrack',
#  'Fastrack',
#  'STYLEDOSE',
#  'SWADESI STUFF',
#  'PANKATI',
#  'SWADESI STUFF',
#  'Acnos',
#  'Generic',
#  'Shocknshop',
#  'SHOPTOSHOP',
#  'TIMEWEAR',
#  'Zesta',
#  'Generic',
#  'TIMEWEAR',
#  'boAt',
#  'Fastrack',
#  'MAGBOT',
#  'TIMEWEAR',
#  'Talgo',
#  'Fossil',
#  'SHUNA',
#  'Analogue',
#  'Reebok',
#  'VILLS LAURRENS',
#  'Decode']

# %%
# fetching name of product
prod_desc = driver.find_elements_by_xpath('//span[@class="a-size-base-plus a-color-base a-text-normal"]')
len(prod_desc)
# Out:
# 68

# %%
# Creating list of product name

Product_name = []
for i in prod_desc:
    Product_name.append(i.text)

Product_name
# Out:
# ['Digital Unisex-Child Watch (Black Dial) (Pack of 2)',
#  "Flaying Sale Analogue Men's Watch (Black Dial)",
#  '7680-Digital Sports Multi Functional Black Dial Watch for Men and Boys',
#  'Super Watch - Refurbished machanical Watch for Men',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Pitch Black)',
#  'SHREE NOVA ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)',
#  'Noise ColorFit Pulse Spo2 Smart Watch with 10 days battery life, 60+ Watch Faces, 1.4" Full Touch HD Display Smartwatch, 24*7 Heart Rate Monitor Smart Band, Sleep Monitoring Smart Watches for Men and Women & IP68 Waterproof (Jet Black)',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Sandy Cream)',
#  'Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED',
#  'RIZZER ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)',
#  'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Black), M (BSW005)',
#  'boAt Flash Edition Smartwatch with Activity Tracker,Multiple Sports Modes,Full Touch 1.3" Screen,Sleep Monitor,Gesture, Camera & Music Control,IP68 Dust,Sweat & Splash Resistance(Lightning Black)',
#  'Smart Watch D116 Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor, BP Monitor, Sports Watch for All Boys & Girls Wristband',
#  "Analog Linear Designer Dial Men’s & Boy's Watch",
#  'Analog Day Date Functioning Stainless Steel Chain Watch for Men',
#  'Fire-Boltt Ninja 2 SpO2 Full Touch Smartwatch with 30 Workout Modes, Heart Rate Tracking, and 100+ Cloud Watch Faces, 7 Days of extensive Battery, Deep Black, M',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Olive Green)',
#  'Tees Analog Black Dial Unisex-Adult Watch-38024PP25',
#  'pTron Force X11 Bluetooth Calling Smartwatch with 1.7" Full Touch Color Display, Real 24/7 Heart Rate Tracking, Multiple Watch Faces, 7Days Runtime, Health/Fitness Trackers & IP68 Waterproof (Black)',
#  'MARVIK® Smart Watch D116 for Xiaomi Mi Note 9 Smart Watch LED with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys & Girls - Black',
#  'Vintage Series Digital Black Dial Unisex Watch - A-158WA-1Q(D011)',
#  "Analog Dial Women's Watch (Pink, 6150SM04)-NM6150SM04 / NL6150SM04",
#  "Analogue Women's Watch (Pink Dial SIlver Colored Strap)",
#  '',
#  '',
#  '',
#  '',
#  '',
#  'S Shock Digital Kids Watch for Boys [7-30 Years]',
#  "Analog Black Dial Men's Watch-SS-GR06612-BLK-CH",
#  'Mesh Strap All Black Men Quartz Watch with Free Premium King Bracelet Water Resistant Feature Rakhi/Raksha Bandhan/Bhai Dooj Gift Pack Combo Analog Watch - for Boys - BT8050+King',
#  'Digital Day and Date Dial Square and Rectangular Display Kids Stylish Watches for Boys and Men Pack of 2',
#  'Fire-Boltt Ninja 2 SpO2 Full Touch Smartwatch with 30 Workout Modes, Heart Rate Tracking and 100+ Cloud Watch Faces, 7 Days of extensive Battery - (Rose Gold), M',
#  'boAt Watch Matrix with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Your own Health Ecosystem & Multiple Sports Modes, 3ATM Water Resistance(Ocean Blue)',
#  'ITRUE Waterproof D20 Touchscreen Smart Watch Bluetooth Smartwatch with Blood Pressure Tracking, Heart Rate Sensor and Basic Functionality (Watch-C)',
#  'Vintage Series Digital Black Dial Unisex Watch - A-158WA-1Q(D011)',
#  "Digital Men's Watch",
#  'Smart Watch D116 Smart Watch, Bluetooth 1.3" Smart Watch LED with Daily Activity Tracker, Heart Rate Sensor, for All Boys & Girls Wristband - Black',
#  "Analogue Men's Watch (Black Dial Black Colored Strap)",
#  'Outdoor Sports Digital Black Dial Mens Boys Watch (Black, Back)',
#  'Fire-Boltt Beast SpO2 1.69” Industry’s Largest Display Size Full Touch Smart Watch with Blood Oxygen Monitoring, Heart Rate Monitor, Multiple Watch Faces & Long Battery Life (Black)',
#  'DECORVAIZ Generic Digital 24 Images Spiderman Projector Watch for Kids(Unisex, Assorted Design)',
#  'Digital Unisex-Child Watch (Black Dial) (Pack of 2)',
#  'Tees Analog Black Dial Unisex-Adult Watch-NG38003PP05W',
#  'reflex 3.0 Unisex activity tracker - Full touch, color display, Heart rate monitor, Dual- tone silicone strap and up to 10 days battery life',
#  'Branded Analogue Black Dial Magnet Watch with Gift Bracelet for Women or Girls and Watch for Girl or Women (Combo of 3)',
#  "Digital Boy's Watch (Multicolored Dial, Multicolored Strap)",
#  'Watch Storage Box Organizer with Faux Leather Finish',
#  "Digital Boy's Watch (Black Dial, Multicolored Strap)",
#  "Analog Multi-Colour Dial Men's Watch - LR-COMBO-01-02-05",
#  'AVIRA T55 Plus Series 6 Smart Watch with Calling & Notification Activity Tracker Band for iOS & Android with Crown Working',
#  'Digital Sports Multi Functional Watch for Mens Boys (Black Dial Colored Strap) -W04BLK',
#  'Activity Tracker',
#  'Analog Number Dial Leather Strap Watch for Men',
#  'Analogue Brown Dial Leather Strap Watch with Wallet, Belt and Sunglass Set for Men & Boys',
#  "Black Dial LED Silicone Bracelet Band M2 Boy's and Girl's Wrist Watch",
#  'Analog Pink Butterfly Silver Dial Stainless Steel Strap Watch for Women - 288SDTL',
#  'boAt Watch Matrix with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Health Ecosystem & Multiple Sports Modes & 3ATM Water Resistance(Twilight Grey)',
#  'Tees Analog Grey Dial Unisex-Adult Watch-NG38003PP08W',
#  'MAGBOT QTX Bluetoth Wireless Smart Watch Fitness Band for Boys, Girls, Men, Women & Kids | Sports Watch for All Smart Phones I Heart Rate and BP Monitor',
#  'Analog Two Hands Slim Watch for Men',
#  "Analog Women's Watch (Black Dial, Black Colored Strap)",
#  "Analog Blue Dial Men's Watch-BQ2311",
#  'SHUNA ID116 Plus Bluetooth Smart Fitness Band Watch with Heart Rate Activity Tracker Waterproof Body, Step and Calorie Counter, Blood Pressure,(12),Activity Tracker for Men/Women',
#  'All Blue Boys Series',
#  'Reebok ActiveFit 1.0 Smartwatch- 1.3" Full-Touch HD Display, SpO2 Sensor, Dynamic HRM, BP & Sleep Monitor, Durable Spindrop Strap, 15+ Sports Modes & Upto 15 Days Battery- RV-ATF-U0-PBIB-BB- Black',
#  "Analogue Men's Watch (Black Dial Black Colored Strap)",
#  "Analogue Men's Watch (Black Dial Black Colored Strap)"]

# %%
#Fetching price of products
fetch_price = driver.find_elements_by_xpath('//span[@class="a-price"]')
print(len(fetch_price))

#creating list for price
price = []
for i in fetch_price:
    price.append(i.text)
    
price
# Out:
# 68
# ['₹290',
#  '₹349',
#  '₹299',
#  '₹999',
#  '₹2,999',
#  '₹471',
#  '₹2,499',
#  '₹2,999',
#  '₹299',
#  '₹350',
#  '₹4,999',
#  '₹2,499',
#  '₹649',
#  '₹329',
#  '₹359',
#  '₹1,899',
#  '₹2,999',
#  '₹850',
#  '₹2,799',
#  '₹587',
#  '₹1,295',
#  '₹1,795',
#  '₹469',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '₹279',
#  '₹374',
#  '₹299',
#  '₹278',
#  '₹1,899',
#  '₹3,999',
#  '₹649',
#  '₹1,295',
#  '₹739',
#  '₹649',
#  '₹379',
#  '₹499',
#  '₹2,999',
#  '₹190',
#  '₹290',
#  '₹795',
#  '₹2,045',
#  '₹299',
#  '₹299',
#  '₹849',
#  '₹299',
#  '₹379',
#  '₹1,380',
#  '₹399',
#  '₹492',
#  '₹289',
#  '₹699',
#  '₹150',
#  '₹349',
#  '₹3,999',
#  '₹795',
#  '₹599',
#  '₹379',
#  '₹279',
#  '₹5,395',
#  '₹699',
#  '₹199',
#  '₹4,499',
#  '₹379',
#  '₹299']

# %%
#Exchange/return not availabl

# %%
#Fetching expected delivery of products
fetch_delvry = driver.find_elements_by_xpath('//span[@class="a-color-base a-text-bold"]')
print(len(fetch_delvry))

#creating list for delivery time
delivery_time = []
for i in fetch_delvry:
    delivery_time.append(i.text)
    
delivery_time
# Out:
# 68
# ['Friday, February 4',
#  'Thursday, February 3',
#  'Wednesday, February 2',
#  'Sunday, February 6',
#  'Today 1PM',
#  'Thursday, February 3',
#  'Tomorrow, February 1',
#  'Today 1PM',
#  'Tomorrow, February 1',
#  'Friday, February 4',
#  'Tomorrow, February 1',
#  'Today 1PM',
#  'Saturday, February 5',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Today 1PM',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Today 1PM',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Friday, February 4',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Wednesday, February 2',
#  'Today 1PM',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Today 1PM',
#  'Tomorrow, February 1',
#  'Saturday, February 5',
#  'Friday, February 4',
#  'Tomorrow, February 1',
#  'Today 1PM',
#  'Friday, February 4',
#  'Friday, February 4',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Wednesday, February 2',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Tomorrow, February 1',
#  'Wednesday, February 2',
#  'Sunday, February 6',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Saturday, February 5',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Thursday, February 3',
#  'Tomorrow, February 1',
#  'Tomorrow, February 1',
#  'Thursday, February 3',
#  'Thursday, February 3',
#  'Tomorrow, February 1',
#  'Friday, February 4',
#  'Thursday, February 3']

# %%
#Fetching URL of products
fetch_url = driver.find_elements_by_xpath('//[@]')
print(len(fetch_url))

#creating list for URLs 
Url = []
for i in fetch_url:
    Url.append(i.text)
Url
# Out:
# 803
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.in',
#  '',
#  'Hello, Sign in\nAccount & Lists',
#  'Returns\n& Orders',
#  '0\nCart',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'All',
#  'Best Sellers',
#  'Mobiles',
#  "Today's Deals",
#  'Electronics',
#  'Customer Service',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Daniel Wellington Brand Store',
#  'Shop Daniel Wellington ',
#  '',
#  '',
#  'Daniel Wellington Petite Melrose 28mm Rose Gold M…',
#  ' 133',
#  '',
#  '',
#  'Sponsored',
#  '',
#  'Digital Unisex-Child Watch (Black Dial) (Pack of 2)',
#  '',
#  '1,791',
#  '₹290\n₹1,499',
#  '',
#  'Sponsored',
#  '',
#  "Flaying Sale Analogue Men's Watch (Black Dial)",
#  '₹349\n₹999',
#  '',
#  'Sponsored',
#  '',
#  '7680-Digital Sports Multi Functional Black Dial Watch for Men and Boys',
#  '',
#  '12',
#  '₹299\n₹1,999',
#  '',
#  'Sponsored',
#  '',
#  'Super Watch - Refurbished machanical Watch for Men',
#  '₹999\n₹1,499',
#  "Amazon's Choice",
#  '',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Pitch Black)',
#  '',
#  '50,242',
#  'Deal of the Day',
#  '₹2,999\n₹7,990',
#  'Best seller',
#  '',
#  'SHREE NOVA ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)',
#  '',
#  '737',
#  '₹471\n₹1,999',
#  '(3 new offers)',
#  '',
#  'Noise ColorFit Pulse Spo2 Smart Watch with 10 days battery life, 60+ Watch Faces, 1.4" Full Touch HD Display Smartwatch, 24*7 Heart Rate Monitor Smart Band, Sleep Monitoring Smart Watches for Men and Women & IP68 Waterproof (Jet Black)',
#  '',
#  '99,959',
#  '₹2,499\n₹4,999',
#  '',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Sandy Cream)',
#  '',
#  '50,242',
#  'Deal of the Day',
#  '₹2,999\n₹7,990',
#  '',
#  'Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED',
#  '',
#  '1,409',
#  '₹299\n₹1,119',
#  '',
#  'RIZZER ID116 Plus Bluetooth Fitness Smart Watch for Men Women and Kids Activity Tracker (Black)',
#  '',
#  '11',
#  '₹350\n₹1,999',
#  'Best seller',
#  '',
#  'Fire-Boltt Ring Bluetooth Calling Smartwatch with SpO2 & 1.7” Metal Body with Blood Oxygen Monitoring, Continuous Heart Rate, Full Touch & Multiple Watch Faces (Black), M (BSW005)',
#  '',
#  '15,203',
#  '₹4,999\n₹9,999',
#  '',
#  'boAt Flash Edition Smartwatch with Activity Tracker,Multiple Sports Modes,Full Touch 1.3" Screen,Sleep Monitor,Gesture, Camera & Music Control,IP68 Dust,Sweat & Splash Resistance(Lightning Black)',
#  '',
#  '10,343',
#  'Deal of the Day',
#  '₹2,499\n₹6,990',
#  '',
#  'Smart Watch D116 Bluetooth 1.3" LED with Daily Activity Tracker, Heart Rate Sensor, BP Monitor, Sports Watch for All Boys & Girls Wristband',
#  '',
#  '97',
#  '₹649\n₹1,999',
#  'Best seller',
#  '',
#  "Analog Linear Designer Dial Men’s & Boy's Watch",
#  '',
#  '16,529',
#  '₹329\n₹2,199',
#  '',
#  'Analog Day Date Functioning Stainless Steel Chain Watch for Men',
#  '',
#  '4,919',
#  '₹359\n₹1,799',
#  '',
#  'Fire-Boltt Ninja 2 SpO2 Full Touch Smartwatch with 30 Workout Modes, Heart Rate Tracking, and 100+ Cloud Watch Faces, 7 Days of extensive Battery, Deep Black, M',
#  '',
#  '508',
#  '₹1,899\n₹4,999',
#  '',
#  'boAt Xtend Smartwatch with Alexa Built-in, 1.69” HD Display, Multiple Watch Faces, Stress Monitor, Heart & SpO2 Monitoring, 14 Sports Modes, Sleep Monitor & 5 ATM Water Resistance(Olive Green)',
#  '',
#  '50,242',
#  'Deal of the Day',
#  '₹2,999\n₹7,990',
#  'Best seller',
#  '',
#  'Tees Analog Black Dial Unisex-Adult Watch-38024PP25',
#  '',
#  '648',
#  '₹850',
#  '',
#  'pTron Force X11 Bluetooth Calling Smartwatch with 1.7" Full Touch Color Display, Real 24/7 Heart Rate Tracking, Multiple Watch Faces, 7Days Runtime, Health/Fitness Trackers & IP68 Waterproof (Black)',
#  '',
#  '79',
#  'Deal of the Day',
#  '₹2,799\n₹7,999',
#  '',
#  'MARVIK® Smart Watch D116 for Xiaomi Mi Note 9 Smart Watch LED with Activity Tracker, Heart Rate Sensor, Sleep Monitor and Basic Functionality for All Boys & Girls - Black',
#  '',
#  '33',
#  '₹587\n₹999',
#  '',
#  'Vintage Series Digital Black Dial Unisex Watch - A-158WA-1Q(D011)',
#  '',
#  '19,778',
#  '₹1,295',
#  '',
#  "Analog Dial Women's Watch (Pink, 6150SM04)-NM6150SM04 / NL6150SM04",
#  '',
#  '6,239',
#  '₹1,795',
#  '',
#  "Analogue Women's Watch (Pink Dial SIlver Colored Strap)",
#  '',
#  '8,557',
#  '₹469\n₹2,599',
#  '(3 new offers)',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sponsored',
#  '',
#  'S Shock Digital Kids Watch for Boys [7-30 Years]',
#  '',
#  '235',
#  '₹279\n₹1,249',
#  '',
#  'Sponsored',
#  '',
#  "Analog Black Dial Men's Watch-SS-GR06612-BLK-CH",
#  '',
#  '3,104',
#  '₹374\n₹1,699',
#  '',
#  'Sponsored',
#  '',
#  'Mesh Strap All Black Men Quartz Watch with Free Premium King Bracelet Water Resistant Feature Rakhi/Raksha Bandhan/Bhai Dooj Gift Pack Combo Analog Watch - for Boys - BT8050+King',
#  '',
#  '22',
#  '₹299\n₹1,699',
#  '',
#  'Sponsored',
#  '',
#  'Digital Day and Date Dial Square and Rectangular Display Kids Stylish Watches for Boys and Men Pack of 2',
#  '',
#  '902',
#  '₹278\n₹599',
#  '',
#  'Fire-Boltt Ninja 2 SpO2 Full Touch Smartwatch with 30 Workout Modes, Heart Rate Tracking and 100+ Cloud Watch Faces, 7 Days of extensive Battery - (Rose Gold), M',
#  '',
#  '508',
#  '₹1,899\n₹4,999',
#  '',
#  'boAt Watch Matrix with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Your own Health Ecosystem & Multiple Sports Modes, 3ATM Water Resistance(Ocean Blue)',
#  '',
#  '111',
#  'Deal of the Day',
#  '₹3,999\n₹8,999',
#  '',
#  'ITRUE Waterproof D20 Touchscreen Smart Watch Bluetooth Smartwatch with Blood Pressure Tracking, Heart Rate Sensor and Basic Functionality (Watch-C)',
#  '',
#  '1',
#  '₹649\n₹699',
#  '',
#  'Vintage Series Digital Black Dial Unisex Watch - A-158WA-1Q(D011)',
#  '',
#  '19,778',
#  '₹1,295',
#  '',
#  "Digital Men's Watch",
#  '',
#  '15,140',
#  '₹739\n₹3,499',
#  '',
#  'Smart Watch D116 Smart Watch, Bluetooth 1.3" Smart Watch LED with Daily Activity Tracker, Heart Rate Sensor, for All Boys & Girls Wristband - Black',
#  '',
#  '98',
#  '₹649\n₹1,899',
#  '',
#  "Analogue Men's Watch (Black Dial Black Colored Strap)",
#  '',
#  '4,649',
#  '₹379\n₹2,499',
#  '',
#  'Outdoor Sports Digital Black Dial Mens Boys Watch (Black, Back)',
#  '',
#  '332',
#  '₹499\n₹1,899',
#  'Best seller',
#  '',
#  'Fire-Boltt Beast SpO2 1.69” Industry’s Largest Display Size Full Touch Smart Watch with Blood Oxygen Monitoring, Heart Rate Monitor, Multiple Watch Faces & Long Battery Life (Black)',
#  '',
#  '8,895',
#  '₹2,999\n₹7,999',
#  '(2 new offers)',
#  'Best seller',
#  '',
#  'DECORVAIZ Generic Digital 24 Images Spiderman Projector Watch for Kids(Unisex, Assorted Design)',
#  '',
#  '6,030',
#  '₹190\n₹399',
#  '(3 new offers)',
#  '',
#  'Digital Unisex-Child Watch (Black Dial) (Pack of 2)',
#  '',
#  '1,791',
#  '₹290\n₹1,499',
#  '',
#  'Tees Analog Black Dial Unisex-Adult Watch-NG38003PP05W',
#  '',
#  '156',
#  '₹795',
#  '',
#  'reflex 3.0 Unisex activity tracker - Full touch, color display, Heart rate monitor, Dual- tone silicone strap and up to 10 days battery life',
#  '',
#  '5,726',
#  '₹2,045\n₹2,995',
#  '',
#  'Branded Analogue Black Dial Magnet Watch with Gift Bracelet for Women or Girls and Watch for Girl or Women (Combo of 3)',
#  '',
#  '1,913',
#  '₹299\n₹999',
#  '',
#  "Digital Boy's Watch (Multicolored Dial, Multicolored Strap)",
#  '',
#  '2,803',
#  '₹299\n₹999',
#  '',
#  '+15 colors/patterns',
#  'Watch Storage Box Organizer with Faux Leather Finish',
#  '',
#  '2,554',
#  '₹849\n₹3,999',
#  '',
#  "Digital Boy's Watch (Black Dial, Multicolored Strap)",
#  '',
#  '3,383',
#  '₹299\n₹1,099',
#  '',
#  "Analog Multi-Colour Dial Men's Watch - LR-COMBO-01-02-05",
#  '',
#  '3,748',
#  '₹379\n₹2,499',
#  '',
#  'AVIRA T55 Plus Series 6 Smart Watch with Calling & Notification Activity Tracker Band for iOS & Android with Crown Working',
#  '',
#  '23',
#  '₹1,380\n₹1,589',
#  '(9 new offers)',
#  '',
#  'Digital Sports Multi Functional Watch for Mens Boys (Black Dial Colored Strap) -W04BLK',
#  '',
#  '59',
#  '₹399\n₹1,299',
#  '',
#  'Activity Tracker',
#  '',
#  '2,557',
#  '₹492\n₹1,999',
#  '',
#  'Analog Number Dial Leather Strap Watch for Men',
#  '',
#  '5,679',
#  '₹289\n₹799',
#  '',
#  'Analogue Brown Dial Leather Strap Watch with Wallet, Belt and Sunglass Set for Men & Boys',
#  '',
#  '484',
#  '₹699\n₹999',
#  '',
#  '+5 colors/patterns',
#  "Black Dial LED Silicone Bracelet Band M2 Boy's and Girl's Wrist Watch",
#  '',
#  '19',
#  '₹150\n₹499',
#  '(7 new offers)',
#  '',
#  'Analog Pink Butterfly Silver Dial Stainless Steel Strap Watch for Women - 288SDTL',
#  '',
#  '28',
#  '₹349\n₹1,299',
#  '',
#  'boAt Watch Matrix with 1.65” AMOLED Display, Always On Mode, Slim Premium Design, Heart Rate & SpO2 Monitoring, Health Ecosystem & Multiple Sports Modes & 3ATM Water Resistance(Twilight Grey)',
#  '',
#  '111',
#  'Deal of the Day',
#  '₹3,999\n₹9,999',
#  '',
#  'Tees Analog Grey Dial Unisex-Adult Watch-NG38003PP08W',
#  '',
#  '238',
#  '₹795',
#  '',
#  'MAGBOT QTX Bluetoth Wireless Smart Watch Fitness Band for Boys, Girls, Men, Women & Kids | Sports Watch for All Smart Phones I Heart Rate and BP Monitor',
#  '',
#  '1,188',
#  '₹599\n₹2,999',
#  '',
#  'Analog Two Hands Slim Watch for Men',
#  '',
#  '7,859',
#  '₹379\n₹2,199',
#  '',
#  "Analog Women's Watch (Black Dial, Black Colored Strap)",
#  '',
#  '659',
#  '₹279\n₹999',
#  '',
#  "Analog Blue Dial Men's Watch-BQ2311",
#  '',
#  '1,576',
#  '₹5,395\n₹8,295',
#  '',
#  'SHUNA ID116 Plus Bluetooth Smart Fitness Band Watch with Heart Rate Activity Tracker Waterproof Body, Step and Calorie Counter, Blood Pressure,(12),Activity Tracker for Men/Women',
#  '',
#  '2',
#  '₹699\n₹1,699',
#  '',
#  'Sponsored',
#  '',
#  'All Blue Boys Series',
#  '',
#  '18',
#  '₹199\n₹1,499',
#  'Best seller',
#  '',
#  'Sponsored',
#  '',
#  'Reebok ActiveFit 1.0 Smartwatch- 1.3" Full-Touch HD Display, SpO2 Sensor, Dynamic HRM, BP & Sleep Monitor, Durable Spindrop Strap, 15+ Sports Modes & Upto 15 Days Battery- RV-ATF-U0-PBIB-BB- Black',
#  '',
#  '9',
#  'Deal of the Day',
#  '₹4,499\n₹7,499',
#  '',
#  'Sponsored',
#  '',
#  "Analogue Men's Watch (Black Dial Black Colored Strap)",
#  '',
#  '4,649',
#  '₹379\n₹2,499',
#  '',
#  'Sponsored',
#  '',
#  "Analogue Men's Watch (Black Dial Black Colored Strap)",
#  '',
#  '559',
#  '₹299\n₹2,199',
#  '',
#  'Fashion & Beauty',
#  '',
#  '',
#  "Customers' Most-Loved Fashion",
#  '',
#  '',
#  'Winter Wear Store',
#  '',
#  '',
#  'Style Feed',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '3',
#  'Next',
#  '',
#  '',
#  '',
#  '',
#  'Watches & Accessories',
#  'Shop Daniel Wellington ',
#  '',
#  '',
#  '',
#  '',
#  'Smartwatches with OLED display and SpO2 sensor',
#  'Shop Reebok Smart Watch ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Visit the help section',
#  'contact us',
#  'Sponsored',
#  '',
#  '',
#  'Get It Today',
#  'Get It by Tomorrow',
#  "Men's Watches",
#  "Men's Wrist Watches",
#  'Smart Watches & Accessories',
#  "Women's Watches",
#  "Women's Wrist Watches",
#  'Activity Trackers',
#  "Boy's Watches",
#  'Wearable Device Accessories',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'See All 13 Departments',
#  '& Up',
#  '& Up',
#  '& Up',
#  '& Up',
#  'TIMEWEAR',
#  'REDUX',
#  'Casio',
#  'Fastrack',
#  'Acnos',
#  'TIMEX',
#  'Generic',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'See more',
#  'Under ₹2,000',
#  '₹2,000 - ₹5,000',
#  '₹5,000 - ₹10,000',
#  '₹10,000 - ₹20,000',
#  'Over ₹20,000',
#  "Today's Deals",
#  'Top Brands',
#  'Made for Amazon',
#  'Premium Brands',
#  'Eligible for Pay On Delivery',
#  '10% Off or more',
#  '25% Off or more',
#  '35% Off or more',
#  '50% Off or more',
#  '60% Off or more',
#  '70% Off or more',
#  'Analogue',
#  'Digital',
#  'Analogue - Digital',
#  'Chronograph',
#  'Quartz',
#  'Automatic',
#  'Ceramic',
#  'Fabric',
#  'Leather',
#  'Nylon',
#  'Plastic',
#  'Resin',
#  'Rose Gold',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'See more',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Casual',
#  'Dress',
#  'Fashion',
#  'Luxury',
#  'Sport',
#  'Wedding',
#  'Up to 9 mm',
#  '10mm - 19mm',
#  '20mm - 29mm',
#  '30mm - 39mm',
#  '40mm & more',
#  'Round',
#  'Square',
#  'Rectangular',
#  'Oval',
#  'Asymmetrical',
#  'Tonneau',
#  'Brass',
#  'Ceramic',
#  'Copper',
#  'Gold Plated',
#  'Plastic',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'See more',
#  'Up to 19 mm',
#  '20 mm - 29 mm',
#  '30 mm - 39 mm',
#  '40 mm - 49 mm',
#  '50 mm & more',
#  'Up to 4 mm',
#  '5 mm - 9 mm',
#  '10 mm - 14 mm',
#  '15 mm - 19 mm',
#  '20 mm & more',
#  'Up to 9 m',
#  '10 m - 29 m',
#  '30 m - 49 m',
#  '50 m - 99 m',
#  '100 m - 199 m',
#  '200 m & more',
#  'Activity Tracker',
#  'Alarm',
#  'Altimeter',
#  'Android',
#  'Back Light',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'See more',
#  'Include Out of Stock',
#  'Sponsored',
#  '',
#  '',
#  'Mumfer Max | 90 Tablets | Iron, Folic Acid Supplement, Vitamin C & Vitamin-B12 | Supports Blood Building, Immunity and Energy',
#  '31',
#  '₹429.00',
#  'Bon K2 HD with Advanced Calcium – 30 Tablets| Enriched with Calcium Citrate Malate, Vitamin D3 and Vitamin K2-7, Multivitamin supplements for Men & Women',
#  '50',
#  '₹249.00',
#  'Reebok ActiveFit 1.0 Smartwatch- 1.3" Full-Touch HD Display, SpO2 Sensor, Dynamic HRM, BP & Sleep Monitor, Durable Spindrop Strap, 15+ Sports Modes & Upto 15 Days Battery- RV-ATF-U0-PBIB-BB- Black',
#  '10',
#  '₹4,499.00',
#  'ZEPOLI - Wall Clock Silent Battery Operated Round Wall Clock Modern Simple Style Decor Clock Non-Ticking (Wooden Brown Clock)',
#  '30',
#  '₹595.65',
#  '',
#  'Sign in',
#  'Start here.',
#  '',
#  'Back to top',
#  'About Us',
#  'Careers',
#  'Press Releases',
#  'Amazon Cares',
#  'Gift a Smile',
#  'Facebook',
#  'Twitter',
#  'Instagram',
#  'Sell on Amazon',
#  'Sell under Amazon Accelerator',
#  'Amazon Global Selling',
#  'Become an Affiliate',
#  'Fulfilment by Amazon',
#  'Advertise Your Products',
#  'Amazon Pay on Merchants',
#  'COVID-19 and Amazon',
#  'Your Account',
#  'Returns Centre',
#  '100% Purchase Protection',
#  'Amazon App Download',
#  'Amazon Assistant Download',
#  'Help',
#  '',
#  'English',
#  'Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'France',
#  'Germany',
#  'Italy',
#  'Japan',
#  'Mexico',
#  'Netherlands',
#  'Poland',
#  'Singapore',
#  'Spain',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'AbeBooks\nBooks, art\n& collectibles',
#  'Amazon Web Services\nScalable Cloud\nComputing Services',
#  'Audible\nDownload\nAudio Books',
#  'DPReview\nDigital\nPhotography',
#  'IMDb\nMovies, TV\n& Celebrities',
#  'Shopbop\nDesigner\nFashion Brands',
#  'Amazon Business\nEverything For\nYour Business',
#  'Prime Now\n2-Hour Delivery\non Everyday Items',
#  'Amazon Prime Music\n75 million songs, ad-free\nOver 10 million podcast episodes',
#  'Conditions of Use & Sale',
#  'Privacy Notice',
#  'Interest-Based Ads']
